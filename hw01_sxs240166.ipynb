# %% [markdown]
# <a href="https://colab.research.google.com/github/sridhartroy/AIML/blob/main/hw01_sxs240166.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
################################################################################
#
# FILE: hw01_sxs240166.py
# AUTHOR:
# Sridhar Srinivasan
# sxs240166
# DESCRIPTION:
# Homework 1
# This program tokenizes Treasure Island text, counts word frequencies,
# sorts them, and prints top results.
# DEPENDENCIES:
# Created with ActiveState Python 3.13.5 (Python version)
# Any dependencies, i.e. extra libraries required to run (like
# datetime, NLTK, re, etc.) : Used "re"
#
################################################################################
